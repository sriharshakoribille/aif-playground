# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pathlib import Path

# %%
# data=np.load('stochastic/brl_tr_online.npy')
data=np.load('../stuff/frozen_lake/brl/brl_tr_pg.npy')
# data=np.load(Path('../stuff/brl_tr_pg.npy').resolve())

# %%
n_eps, n_runs = data.shape

# %%
df = pd.DataFrame(data={"Episode": np.tile(np.arange(n_eps),reps=n_runs),
                        "Rewards": data.flatten('F')})

# %%
a = sns.lineplot(x="Episode", y="Rewards", data=df)
# a.set_title("Q-Learning with deterministic environment")
plt.show()

# %%
steps = np.load('../stuff/frozen_lake/brl/brl_ts_pg_online.npy')

# %%
df_steps = pd.DataFrame(data={"Episode": np.tile(np.arange(n_eps),reps=n_runs),
                        "Steps": steps.flatten('F')})

# %%
a = sns.lineplot(x="Episode", y="Steps", data=df_steps)
plt.show()
